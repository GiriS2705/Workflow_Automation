# %%
# %sql
CREATE CATALOG IF NOT EXISTS fmcg;
USE CATALOG workauto;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS workauto.gold;
CREATE SCHEMA IF NOT EXISTS workauto.silver;
CREATE SCHEMA IF NOT EXISTS workauto.bronze;
